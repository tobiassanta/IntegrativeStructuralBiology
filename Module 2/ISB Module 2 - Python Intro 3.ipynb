# %% [markdown]
# # Exercise 1

# %%
# Problem 1
triplet = (1, 2, 3)

# %%
# Problem 2
x, y, z = triplet

# %%
# Problem 3
quartet = (1, 2, 3, 4)
x, y, z = quartet #error because of more elements in quartet --> use dummy variable instead
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 # Problem 3
#       2 quartet = (1, 2, 3, 4)
# ----> 3 x, y, z = quartet #error because of more elements in quartet --> use dummy variable instead
#
# ValueError: too many values to unpack (expected 3, got 4)

# %%
# Problem 4
x, y, z = quartet[:3]

# or one could use dummy variable

x, y, z, _ = quartet

# %% [markdown]
# # Exercise 2

# %%
#Problem 1
personal = {
    'firstname': 'Tobias',
    'lastname': 'Sørensen',
    'age': '23'
}

# %%
# Problem 2
personal['address'] = 'Ingrid Marievej'

# %%
# Problem 3
print(personal.keys())
# Out:
# dict_keys(['firstname', 'lastname', 'age', 'address'])

# %%
# Problem 4
personal['name'] = personal.pop('firstname') + ' ' + \
                   personal.pop('lastname')
personal
# Out:
# {'age': '23', 'address': 'Ingrid Marievej', 'name': 'Tobias Sørensen'}
