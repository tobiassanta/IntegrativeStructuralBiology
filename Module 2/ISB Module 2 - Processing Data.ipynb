# %%
import matplotlib as plt
import numpy as np
import sympy as sp
import scienceplots
plt.style.use(['science','grid','notebook'])

# %% [markdown]
# # Problem 1 - Reading the Data

# %%
with open('amide.s2_exp') as input_file:
    data_as_str = input_file.readlines()

# %% [markdown]
# # Problem 2 - Iteration and Stripping of Lines

# %%
for line in data_as_str:
    stripped_line = line.strip('\n')
    print(line_stripped)
# Out:
# 2 0.838 amide
# 3 0.884 amide
# 4 0.898 amide
# 5 0.83 amide
# 6 0.86 amide
# 7 0.86 amide
# 8 0.772 amide
# 10 0.736 amide
# 11 0.709 amide
# 12 0.756 amide
# 13 0.845 amide
# 14 0.83 amide
# 15 0.823 amide
# 16 0.777 amide
# 17 0.877 amide
# 18 0.849 amide
# 20 0.842 amide
# 21 0.9 amide
# 22 0.852 amide
# 23 0.905 amide
# 25 0.886 amide
# 26 0.858 amide
# 27 0.916 amide
# 28 0.897 amide
# 29 0.89 amide
# 30 0.886 amide
# 31 0.798 amide
# 32 0.895 amide
# 33 0.855 amide
# 34 0.851 amide
# 35 0.854 amide
# 36 0.784 amide
# 39 0.852 amide
# 40 0.865 amide
# 41 0.852 amide
# 42 0.831 amide
# 43 0.828 amide
# 44 0.837 amide
# 45 0.872 amide
# 46 0.84 amide
# 47 0.821 amide
# 48 0.843 amide
# 49 0.752 amide
# 50 0.836 amide
# 51 0.796 amide
# 52 0.788 amide
# 54 0.855 amide
# 55 0.868 amide
# 56 0.901 amide
# 57 0.871 amide
# 58 0.892 amide
# 59 0.866 amide
# 60 0.883 amide
# 61 0.858 amide
# 62 0.702 amide
# 63 0.817 amide
# 64 0.878 amide
# 65 0.87 amide
# 66 0.841 amide
# ...

# %% [markdown]
# # Problem 3 - Splitting

# %%
for line in data_as_str:
    stripped_line= line.strip('\n')
    split_line  = stripped_line.split()
    print(split_line)
# Out:
# ['2', '0.838', 'amide']
# ['3', '0.884', 'amide']
# ['4', '0.898', 'amide']
# ['5', '0.83', 'amide']
# ['6', '0.86', 'amide']
# ['7', '0.86', 'amide']
# ['8', '0.772', 'amide']
# ['10', '0.736', 'amide']
# ['11', '0.709', 'amide']
# ['12', '0.756', 'amide']
# ['13', '0.845', 'amide']
# ['14', '0.83', 'amide']
# ['15', '0.823', 'amide']
# ['16', '0.777', 'amide']
# ['17', '0.877', 'amide']
# ['18', '0.849', 'amide']
# ['20', '0.842', 'amide']
# ['21', '0.9', 'amide']
# ['22', '0.852', 'amide']
# ['23', '0.905', 'amide']
# ['25', '0.886', 'amide']
# ['26', '0.858', 'amide']
# ['27', '0.916', 'amide']
# ['28', '0.897', 'amide']
# ['29', '0.89', 'amide']
# ['30', '0.886', 'amide']
# ['31', '0.798', 'amide']
# ['32', '0.895', 'amide']
# ['33', '0.855', 'amide']
# ['34', '0.851', 'amide']
# ['35', '0.854', 'amide']
# ['36', '0.784', 'amide']
# ['39', '0.852', 'amide']
# ['40', '0.865', 'amide']
# ['41', '0.852', 'amide']
# ['42', '0.831', 'amide']
# ['43', '0.828', 'amide']
# ...

# %% [markdown]
# # Problem 4 - Creating Data List

# %%
data_list = []

for line in data_as_str:
    stripped_line = line.strip('\n')
    split_line = stripped_line.split()
    data_list.append(split_line)

print(data_list)
# Out:
# [['2', '0.838', 'amide'], ['3', '0.884', 'amide'], ['4', '0.898', 'amide'], ['5', '0.83', 'amide'], ['6', '0.86', 'amide'], ['7', '0.86', 'amide'], ['8', '0.772', 'amide'], ['10', '0.736', 'amide'], ['11', '0.709', 'amide'], ['12', '0.756', 'amide'], ['13', '0.845', 'amide'], ['14', '0.83', 'amide'], ['15', '0.823', 'amide'], ['16', '0.777', 'amide'], ['17', '0.877', 'amide'], ['18', '0.849', 'amide'], ['20', '0.842', 'amide'], ['21', '0.9', 'amide'], ['22', '0.852', 'amide'], ['23', '0.905', 'amide'], ['25', '0.886', 'amide'], ['26', '0.858', 'amide'], ['27', '0.916', 'amide'], ['28', '0.897', 'amide'], ['29', '0.89', 'amide'], ['30', '0.886', 'amide'], ['31', '0.798', 'amide'], ['32', '0.895', 'amide'], ['33', '0.855', 'amide'], ['34', '0.851', 'amide'], ['35', '0.854', 'amide'], ['36', '0.784', 'amide'], ['39', '0.852', 'amide'], ['40', '0.865', 'amide'], ['41', '0.852', 'amide'], ['42', '0.831', 'amide'], ['43', '0.828', 'amide'], ['44', '0.837', 'amide'], ['45', '0.872', 'amide'
# ...

# %% [markdown]
# # Problem 5 - Creating Integers and Floats instead of Strings

# %%
data_list = []

for line in data_as_str:
    stripped_line       = line.strip('\n')
    split_line          = stripped_line.split()

    split_line[0]       = int(split_line[0])
    split_line[1]       = float(split_line[1])

    data_list.append(split_line)

print(type(data_list[0][0]), type(data_list[0][1]))
data_list
# Out:
# <class 'int'> <class 'float'>
# [[2, 0.838, 'amide'],
#  [3, 0.884, 'amide'],
#  [4, 0.898, 'amide'],
#  [5, 0.83, 'amide'],
#  [6, 0.86, 'amide'],
#  [7, 0.86, 'amide'],
#  [8, 0.772, 'amide'],
#  [10, 0.736, 'amide'],
#  [11, 0.709, 'amide'],
#  [12, 0.756, 'amide'],
#  [13, 0.845, 'amide'],
#  [14, 0.83, 'amide'],
#  [15, 0.823, 'amide'],
#  [16, 0.777, 'amide'],
#  [17, 0.877, 'amide'],
#  [18, 0.849, 'amide'],
#  [20, 0.842, 'amide'],
#  [21, 0.9, 'amide'],
#  [22, 0.852, 'amide'],
#  [23, 0.905, 'amide'],
#  [25, 0.886, 'amide'],
#  [26, 0.858, 'amide'],
#  [27, 0.916, 'amide'],
#  [28, 0.897, 'amide'],
#  [29, 0.89, 'amide'],
#  [30, 0.886, 'amide'],
#  [31, 0.798, 'amide'],
#  [32, 0.895, 'amide'],
#  [33, 0.855, 'amide'],
#  [34, 0.851, 'amide'],
#  [35, 0.854, 'amide'],
#  [36, 0.784, 'amide'],
#  [39, 0.852, 'amide'],
#  [40, 0.865, 'amide'],
#  [41, 0.852, 'amide'],
#  [42, 0.831, 'amide'],
#  [43, 0.828, 'amide'],
#  [44, 0.837, 'amide'],
#  [45, 0.872, 'amide'],
# ...

# %% [markdown]
# # Bonus Problem - Dictionaries

# %%
# Making dictionary with keys and empty lists associated with them in the beginning
residue_list = []
S2_list      = []
type_list    = []

for data_point in data_list:
    residue_list.append(data_point[0])
    S2_list.append(data_point[1])
    type_list.append(data_point[2])

data = {'residue': residue_list, 
        'S2': S2_list, 
        'type':type_list
}

#data['residue'][5]
#data['S2'][5]
#data['type'][5]
